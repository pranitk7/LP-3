# %%
import requests

print(requests.get("https://github.com/pranitk7/LP-3/blob/main/ML/Emailspam.ipynb?short_path=0540a66").text)
# Out:
# {"payload":{"allShortcutsEnabled":false,"fileTree":{"ML":{"items":[{"name":"Emailspam.ipynb","path":"ML/Emailspam.ipynb","contentType":"file"},{"name":"diabetes.ipynb","path":"ML/diabetes.ipynb","contentType":"file"},{"name":"gradient.ipynb","path":"ML/gradient.ipynb","contentType":"file"},{"name":"uberPricepredict.ipynb","path":"ML/uberPricepredict.ipynb","contentType":"file"}],"totalCount":4},"":{"items":[{"name":"BT","path":"BT","contentType":"directory"},{"name":"DAA","path":"DAA","contentType":"directory"},{"name":"ML","path":"ML","contentType":"directory"}],"totalCount":3}},"fileTreeProcessingTime":3.196376,"foldersToFetch":[],"reducedMotionEnabled":null,"repo":{"id":714743186,"defaultBranch":"main","name":"LP-3","ownerLogin":"pranitk7","currentUserCanPush":false,"isFork":false,"isEmpty":false,"createdAt":"2023-11-05T18:25:52.000Z","ownerAvatar":"https://avatars.githubusercontent.com/u/91371055?v=4","public":true,"private":false,"isOrgOwned":false},"symbolsExpanded":false,"tree
# ...
